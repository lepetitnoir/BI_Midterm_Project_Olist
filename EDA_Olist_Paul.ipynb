# %% [markdown]
# # Importing Data

# %%
import pandas as pd

# %%
closed_deals = pd.read_csv('Data/closed_deals.csv')

# %%
customers = pd.read_csv('Data/customers.csv')

# %%
geolocation = pd.read_csv('Data/geolocation.csv')

# %%
marketing_ql = pd.read_csv('Data/marketing_qualified_leads.csv')

# %%
order_customer = pd.read_csv('Data/order_costumer_items_paids.csv')

# %%
order_items = pd.read_csv('Data/order_items.csv')

# %%
order_payments = pd.read_csv('Data/order_payments.csv')

# %% [markdown]
# # Checking for standardized column names

# %%
closed_deals['lead_behaviour_profile'].head()
# Out:
# 0      cat
# 1    eagle
# 2      cat
# 3      NaN
# 4     wolf
# Name: lead_behaviour_profile, dtype: object

# %% [markdown]
# # Removing duplicates

# %%
closed_deals = closed_deals.drop_duplicates()

# %%
customers = customers.drop_duplicates()

# %%
geolocation = geolocation.drop_duplicates()

# %%
marketing_ql = marketing_ql.drop_duplicates()

# %%
order_customer = order_customer.drop_duplicates()

# %%
order_items = order_items.drop_duplicates()

# %%
order_payments = order_payments.drop_duplicates()

# %% [markdown]
# # Deleting/Rearranging Colums

# %%
closed_deals.head()
# Out:
#                              mql_id                         seller_id  \
# 0  5420aad7fec3549a85876ba1c529bd84  2c43fb513632d29b3b58df74816f1b06
# 1  a555fb36b9368110ede0f043dfc3b9a0  bbb7d7893a450660432ea6652310ebb7
# 2  327174d3648a2d047e8940d7d15204ca  612170e34b97004b3ba37eae81836b4c
# 3  f5fee8f7da74f4887f5bcae2bafb6dd6  21e1781e36faf92725dde4730a88ca0f
# 4  ffe640179b554e295c167a2f6be528e0  ed8cb7b190ceb6067227478e48cf8dde
#
#                              sdr_id                             sr_id  \
# 0  a8387c01a09e99ce014107505b92388c  4ef15afb4b2723d8f3d81e51ec7afefe
# 1  09285259593c61296eef10c734121d5b  d3d1e91a157ea7f90548eef82f1955e3
# 2  b90f87164b5f8c2cfa5c8572834dbe3f  6565aa9ce3178a5caf6171827af3a9ba
# 3  56bf83c4bb35763a51c2baab501b4c67  d3d1e91a157ea7f90548eef82f1955e3
# 4  4b339f9567d060bcea4f5136b9f5949e  d3d1e91a157ea7f90548eef82f1955e3
#
#               won_date business_segment      lead_type lead_behaviour_profile  \
# 0  2018-02-26 19:58:54              pet  online_medium                    cat
# 1  2018-05-08 20:17:59  car_accessories       industry                  eagle
# 2  2018-06-05 17:27:23  home_appliances     online_big                    cat
# 3  2018-01-17 13:51:03       food_drink   online_small                    NaN
# 4  2018-07-03 20:17:45  home_appliances       industry                   wolf
#
#   has_company has_gtin average_stock business_type  \
# 0         NaN      NaN           NaN      reseller
# 1         NaN      NaN           NaN      reseller
# 2         NaN      NaN           NaN      reseller
# 3         NaN      NaN           NaN      reseller
# 4         NaN      NaN           NaN  manufacturer
#
#    declared_product_catalog_size  declared_monthly_revenue
# 0                            NaN                       0.0
# 1                            NaN                       0.0
# 2                            NaN                       0.0
# 3                            NaN                       0.0
# 4                            NaN                       0.0

# %%
closed_deals = closed_deals.drop(['won_date', 'lead_behaviour_profile'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 closed_deals = closed_deals.drop(['won_date', 'lead_behaviour_profile'], axis = 1)
#
# File /opt/anaconda3/envs/DA/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/DA/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File /opt/anaconda3/envs/DA/lib/python3.9/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File /opt/anaconda3/envs/DA/lib/python3.9/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File /opt/anaconda3/envs/DA/lib/python3.9/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['won_date', 'lead_behaviour_profile'] not found in axis"

# %%
closed_deals = closed_deals.drop(['mql_id','seller_id'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [73], in <cell line: 1>()
# ----> 1 closed_deals = closed_deals.drop(['mql_id','seller_id'], axis = 1)
#
# File /opt/anaconda3/envs/DA/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/DA/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File /opt/anaconda3/envs/DA/lib/python3.9/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File /opt/anaconda3/envs/DA/lib/python3.9/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File /opt/anaconda3/envs/DA/lib/python3.9/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['mql_id'] not found in axis"

# %%
closed_deals = closed_deals.drop(['seller_id'], axis = 1)

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers = customers.drop(['customer_zip_code_prefix'], axis = 1)

# %%
customers = customers.drop(['customer_id'], axis = 1)

# %%
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
geolocation = geolocation.drop(['geolocation_zip_code_prefix', 'geolocation_city'], axis = 1)

# %%
marketing_ql.head()
# Out:
#                              mql_id first_contact_date  \
# 0  dac32acd4db4c29c230538b72f8dd87d         2018-02-01
# 1  8c18d1de7f67e60dbd64e3c07d7e9d5d         2017-10-20
# 2  b4bc852d233dfefc5131f593b538befa         2018-03-22
# 3  6be030b81c75970747525b843c1ef4f8         2018-01-22
# 4  5420aad7fec3549a85876ba1c529bd84         2018-02-21
#
#                     landing_page_id          origin
# 0  88740e65d5d6b056e0cda098e1ea6313          social
# 1  007f9098284a86ee80ddeb25d53e0af8     paid_search
# 2  a7982125ff7aa3b2054c6e44f9d28522  organic_search
# 3  d45d558f0daeecf3cccdffe3c59684aa           email
# 4  b48ec5f3b04e9068441002a19df93c6c  organic_search

# %%
marketing_ql = marketing_ql.drop(['landing_page_id'], axis = 1)

# %%
order_customer.head()
# Out:
#                            order_id   customer_city  \
# 0  f11b36b3bc7bacf06deef862ed611f02         guaruja
# 1  0daf1f0e67b534ad873ba61c5d6ad7d3  rio de janeiro
# 2  4a5cc9b4e332e03d76bf553a7f2fa5d3    belford roxo
# 3  47770eb9100c2d0c44946d9cf07ec65d      vianopolis
# 4  5f69f6bf68dce110479aa0bb515b47c8  ribeirao pires
#
#                         customer_id order_status  order_item_id  price  \
# 0  ae8db0691449a44352e7d535ddf78c5e    delivered              1  109.9
# 1  1681471e9172d7e12ba08e9ac9e8628b    delivered              1  135.0
# 2  a4a00c41b5e3ed88bf0e0bb96576c2b2    delivered              1  159.9
# 3  41ce2a54c0b03bf3443c3d931a367089    delivered              1  159.9
# 4  4cd274ce8ba240b1cff6480fa9911df1    delivered              1   30.0
#
#    freight_value  final_price
# 0          14.86       124.76
# 1          18.20       153.20
# 2          16.88       176.78
# 3          19.22       179.12
# 4           8.72        38.72

# %%
order_customer = order_customer.drop(['order_id', 'customer_city', 'customer_id'], axis = 1)

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14

# %%
order_items = order_items.drop(['order_id', 'seller_id'], axis = 1)

# %%
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments = order_payments.drop(['order_id'], axis = 1)

# %% [markdown]
# # Checking for data types

# %%
closed_deals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 842 entries, 0 to 841
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   seller_id                      842 non-null    object
#  1   sdr_id                         842 non-null    object
#  2   sr_id                          842 non-null    object
#  3   business_segment               841 non-null    object
#  4   lead_type                      836 non-null    object
#  5   has_company                    63 non-null     object
#  6   has_gtin                       64 non-null     object
#  7   average_stock                  66 non-null     object
#  8   business_type                  832 non-null    object
#  9   declared_product_catalog_size  69 non-null     float64
#  10  declared_monthly_revenue       842 non-null    float64
# dtypes: float64(2), object(9)
# memory usage: 78.9+ KB

# %% [markdown]
# # Searching for missing values

# %%
closed_deals.isnull()
# Out:
#      seller_id  sdr_id  sr_id  business_segment  lead_type  has_company  \
# 0        False   False  False             False      False         True
# 1        False   False  False             False      False         True
# 2        False   False  False             False      False         True
# 3        False   False  False             False      False         True
# 4        False   False  False             False      False         True
# ..         ...     ...    ...               ...        ...          ...
# 837      False   False  False             False      False         True
# 838      False   False  False             False      False         True
# 839      False   False  False             False      False         True
# 840      False   False  False             False      False         True
# 841      False   False  False             False      False         True
#
#      has_gtin  average_stock  business_type  declared_product_catalog_size  \
# 0        True           True          False                           True
# 1        True           True          False                           True
# 2        True           True          False                           True
# 3        True           True          False                           True
# 4        True           True          False                           True
# ..        ...            ...            ...                            ...
# 837      True           True          False                           True
# 838      True           True          False                          False
# 839      True           True          False                           True
# 840      True           True          False                           True
# 841      True           True          False                           True
#
#      declared_monthly_revenue
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False
# ..                        ...
# 837                     False
# 838                     False
# 839                     False
# 840                     False
# 841                     False
#
# [842 rows x 11 columns]

# %%
closed_deals = closed_deals.drop(['has_company', 'has_gtin', 'average_stock'], axis = 1)

# %%
customers.isnull()
# Out:
#        customer_unique_id  customer_city  customer_state
# 0                   False          False           False
# 1                   False          False           False
# 2                   False          False           False
# 3                   False          False           False
# 4                   False          False           False
# ...                   ...            ...             ...
# 99436               False          False           False
# 99437               False          False           False
# 99438               False          False           False
# 99439               False          False           False
# 99440               False          False           False
#
# [99441 rows x 3 columns]

# %%
geolocation.isnull()
# Out:
#          geolocation_lat  geolocation_lng  geolocation_state
# 0                  False            False              False
# 1                  False            False              False
# 2                  False            False              False
# 3                  False            False              False
# 4                  False            False              False
# ...                  ...              ...                ...
# 1000155            False            False              False
# 1000156            False            False              False
# 1000157            False            False              False
# 1000158            False            False              False
# 1000161            False            False              False
#
# [738327 rows x 3 columns]

# %%
geolocation = geolocation.dropna()

# %%
marketing_ql.isnull()
# Out:
#       mql_id  first_contact_date  origin
# 0      False               False   False
# 1      False               False   False
# 2      False               False   False
# 3      False               False   False
# 4      False               False   False
# ...      ...                 ...     ...
# 7995   False               False   False
# 7996   False               False   False
# 7997   False               False   False
# 7998   False               False   False
# 7999   False               False   False
#
# [8000 rows x 3 columns]

# %%
order_customer.isnull()
# Out:
#         order_status  order_item_id  price  freight_value  final_price
# 0              False          False  False          False        False
# 1              False          False  False          False        False
# 2              False          False  False          False        False
# 3              False          False  False          False        False
# 4              False          False  False          False        False
# ...              ...            ...    ...            ...          ...
# 111380         False          False  False          False        False
# 111381         False          False  False          False        False
# 111382         False          False  False          False        False
# 111383         False          False  False          False        False
# 111384         False          False  False          False        False
#
# [111385 rows x 5 columns]

# %%
order_items.isnull()
# Out:
#         order_item_id  product_id  shipping_limit_date  price  freight_value
# 0               False       False                False  False          False
# 1               False       False                False  False          False
# 2               False       False                False  False          False
# 3               False       False                False  False          False
# 4               False       False                False  False          False
# ...               ...         ...                  ...    ...            ...
# 112645          False       False                False  False          False
# 112646          False       False                False  False          False
# 112647          False       False                False  False          False
# 112648          False       False                False  False          False
# 112649          False       False                False  False          False
#
# [112650 rows x 5 columns]

# %%
order_payments.isnull()
# Out:
#         payment_sequential  payment_type  payment_installments  payment_value
# 0                    False         False                 False          False
# 1                    False         False                 False          False
# 2                    False         False                 False          False
# 3                    False         False                 False          False
# 4                    False         False                 False          False
# ...                    ...           ...                   ...            ...
# 103881               False         False                 False          False
# 103882               False         False                 False          False
# 103883               False         False                 False          False
# 103884               False         False                 False          False
# 103885               False         False                 False          False
#
# [103886 rows x 4 columns]

# %% [markdown]
# # Dividing Data in numerials and categorials

# %%
closed_deals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 842 entries, 0 to 841
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   sdr_id                         842 non-null    object
#  1   sr_id                          842 non-null    object
#  2   business_segment               841 non-null    object
#  3   lead_type                      836 non-null    object
#  4   business_type                  832 non-null    object
#  5   declared_product_catalog_size  69 non-null     float64
#  6   declared_monthly_revenue       842 non-null    float64
# dtypes: float64(2), object(5)
# memory usage: 52.6+ KB

# %%
closed_deals.to_csv("closed_deals_cleaned.csv")

# %%
closed_deals_numericals = closed_deals._get_numeric_data()

# %%
closed_deals_numericals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 842 entries, 0 to 841
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   declared_product_catalog_size  69 non-null     float64
#  1   declared_monthly_revenue       842 non-null    float64
# dtypes: float64(2)
# memory usage: 19.7 KB

# %%
closed_deals_categoricals = closed_deals.drop(['declared_product_catalog_size', 'declared_monthly_revenue'], axis = 1)

# %%
closed_deals_categoricals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 842 entries, 0 to 841
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   seller_id         842 non-null    object
#  1   sdr_id            842 non-null    object
#  2   sr_id             842 non-null    object
#  3   business_segment  841 non-null    object
#  4   lead_type         836 non-null    object
#  5   business_type     832 non-null    object
# dtypes: object(6)
# memory usage: 46.0+ KB

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99441 entries, 0 to 99440
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_unique_id  99441 non-null  object
#  1   customer_city       99441 non-null  object
#  2   customer_state      99441 non-null  object
# dtypes: object(3)
# memory usage: 3.0+ MB

# %%
customers_numerical = []

# %%
customers_categorical = customers

# %%
customers.to_csv("customers_cleaned.csv")

# %%
geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 738327 entries, 0 to 1000161
# Data columns (total 3 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   geolocation_lat    738327 non-null  float64
#  1   geolocation_lng    738327 non-null  float64
#  2   geolocation_state  738327 non-null  object
# dtypes: float64(2), object(1)
# memory usage: 22.5+ MB

# %%
geolocation.to_csv("geolocation_cleaned.csv")

# %%
marketing_ql.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8000 entries, 0 to 7999
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   mql_id              8000 non-null   object
#  1   first_contact_date  8000 non-null   object
#  2   origin              7940 non-null   object
# dtypes: object(3)
# memory usage: 250.0+ KB

# %%
marketing_ql.to_csv("marketing_ql_cleaned.csv")

# %%
marketing_ql_numericals = []

# %%
marketing_ql_categoricals = marketing_ql

# %%
order_customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111385 entries, 0 to 111384
# Data columns (total 5 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   order_status   111385 non-null  object
#  1   order_item_id  111385 non-null  int64
#  2   price          111385 non-null  float64
#  3   freight_value  111385 non-null  float64
#  4   final_price    111385 non-null  float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 5.1+ MB

# %%
order_customer.to_csv("order_customer_cleaned.csv")

# %%
order_customer['order_item_id'] = order_customer['order_item_id'].astype(str)

# %%
order_customer_numericals = order_customer._get_numeric_data()

# %%
order_customer_numericals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111385 entries, 0 to 111384
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   price          111385 non-null  float64
#  1   freight_value  111385 non-null  float64
#  2   final_price    111385 non-null  float64
# dtypes: float64(3)
# memory usage: 3.4 MB

# %%
order_customer_categoricals = order_customer.drop(['price', 'freight_value', 'final_price'], axis = 1)

# %%
order_customer_categoricals.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111385 entries, 0 to 111384
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   order_status   111385 non-null  object
#  1   order_item_id  111385 non-null  object
# dtypes: object(2)
# memory usage: 2.5+ MB

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 5 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_item_id        112650 non-null  int64
#  1   product_id           112650 non-null  object
#  2   shipping_limit_date  112650 non-null  object
#  3   price                112650 non-null  float64
#  4   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 5.2+ MB

# %%
order_items.to_csv("order_items_cleaned.csv")

# %%
order_items

# %%
order_items_numerical = order_items._get_numeric_data()

# %%
order_items_numerical = order_items_numerical.drop(['freight_value'], axis = 1)

# %%
order_items_numerical = order_items_numerical.drop(['order_item_id'], axis = 1)

# %%
order_items_numerical.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   price   112650 non-null  float64
# dtypes: float64(1)
# memory usage: 1.7 MB

# %%
order_items_categorical = order_items.drop(['price', 'freight_value'], axis = 1)

# %%
order_items_categorical['order_item_id'] = order_items_categorical['order_item_id'].astype(str)

# %%
order_items_categorical.info()

# %%
order_payments.info()

# %%
order_payments['payment_sequential'] = order_payments['payment_sequential'].astype(str)

# %%
order_payments['payment_installments'] = order_payments['payment_installments'].astype(str)

# %%
order_payments.info()

# %%
order_payments_numericals = order_payments._get_numeric_data()

# %%
order_payments_numericals.info()

# %%
order_payments_categoricals = order_payments.drop(['payment_value'], axis = 1)

# %%
order_payments_categoricals.info()

# %%
order_payments.to_csv("order_payments_cleaned.csv")

# %% [markdown]
# # Importing joins

# %%
join_oc = pd.read_csv('Join/join_orders_customer.csv')

# %%
join_oc = join_oc.dropna()

# %% [markdown]
# # Dropping join columns (duplicates, not needed)

# %%
# rename Pandas columns to lower case

join_oc.columns = join_oc.columns.str.lower()

# %%
join_oc = join_oc.drop(['order_item_id.1', 'freight_value.1', 'order_item_id.2', 'order_status.1', 'product_id.1', 'customer_city.1'], axis = 1)

# %%
join_oc = join_oc.drop(['price.1'], axis = 1)

# %%
join_oc = join_oc.drop(['customer_zip_code_prefix'], axis = 1)

# %%
join_oc['year'] = join_oc['year'].astype(int)

# %%
join_oc['order_item_id'] = join_oc['order_item_id'].astype(str)

# %%
#join_oc.to_csv("clean_oc.csv")

# %%
#clean_oc = pd.read_csv('Join/clean_oc.csv')
# Out:
# /var/folders/z7/h39z8zd55hb3q_stjqd0sqgm0000gn/T/ipykernel_736/823580705.py:1: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   clean_oc = pd.read_csv('Join/clean_oc.csv')

# %%
join_oc
# Out:
#                               customer_id                          order_id  \
# 0        e3f62212035039c920a8409127b09a41  05302619b1bff6733f64a97851af68cd
# 1        d8eaef18d54f26637bdd57fb1254bbb6  ffe2b9e50ccbd9695f42c906f6d9010c
# 2        fa02a9d0399654a2a97b861ec8ef7897  f174b7bb70b31bea3dbfdf7cf9719ce5
# 3        669b06cabc9d39c1bcc52e6889e1318d  13b825fdc28948500cfc7a03eb975fbc
# 4        8cb759609b468ec8d01195f328535068  2c6c5c881336bcec2d8c89cb05184a81
# ...                                   ...                               ...
# 1473316  53c554aead19ea0f3be4a75e0a2332bd  3dc295e279315e7e81cfed73795c77a6
# 1473317  53c554aead19ea0f3be4a75e0a2332bd  3dc295e279315e7e81cfed73795c77a6
# 1473318  53c554aead19ea0f3be4a75e0a2332bd  3dc295e279315e7e81cfed73795c77a6
# 1473319  53c554aead19ea0f3be4a75e0a2332bd  3dc295e279315e7e81cfed73795c77a6
# 1473320  53c554aead19ea0f3be4a75e0a2332bd  3dc295e279315e7e81cfed73795c77a6
#
#                 customer_city order_status order_item_id   price  \
# 0              rio de janeiro    delivered           1.0   29.99
# 1                      santos    delivered           1.0  185.99
# 2                   itabirito    delivered           1.0  104.49
# 3        boa esperanca do sul    delivered           1.0   31.00
# 4                     niteroi    delivered           2.0  119.90
# ...                       ...          ...           ...     ...
# 1473316             sao paulo    delivered           4.0   90.00
# 1473317             sao paulo    delivered           4.0   90.00
# 1473318             sao paulo    delivered           3.0   90.00
# 1473319             sao paulo    delivered           3.0   90.00
# 1473320             sao paulo    delivered           3.0   90.00
#
#          freight_value  final_price                        product_id  \
# 0                14.10        44.09  4473f3e5c65952b074ef987fa5c24662
# 1                15.38       201.37  3488d2ce36e718097c1509444289ef7f
# 2                12.44       116.93  590d6cb76092faa04d717fe406c66f88
# 3                11.85        42.85  e9f4a2b16f44a27e454037659cceb20f
# 4                24.81       144.71  c99666957e5d14717bd1d5ba0fd33f53
# ...                ...          ...                               ...
# 1473316          20.58       110.58  7fb04722aba7a2b632bac8f9819796f3
# 1473317          20.58       110.58  7fb04722aba7a2b632bac8f9819796f3
# 1473318          20.58       110.58  7fb04722aba7a2b632bac8f9819796f3
# 1473319          20.58       110.58  7fb04722aba7a2b632bac8f9819796f3
# 1473320          20.58       110.58  7fb04722aba7a2b632bac8f9819796f3
#
#                                 seller_id  shipping_limit_date  year  \
# 0        ea8482cd71df3c1969d7b9473ff13abc  2018-01-29 04:36:53  2018
# 1        26d8a1c7c75d513045798992ead43aa2  2018-03-22 13:15:33  2018
# 2        4049512728d969bec69f84088b012416  2018-02-15 23:52:21  2018
# 3        b4ffb71f0cb1b1c3d63fad021ecf93e1  2018-02-22 11:30:22  2018
# 4        79ebd9a61bac3eaf882805ed4ecfa12a  2018-04-02 20:49:00  2018
# ...                                   ...                  ...   ...
# 1473316  f3b80352b986ab4d1057a4b724be19d0  2018-07-03 10:50:58  2018
# 1473317  f3b80352b986ab4d1057a4b724be19d0  2018-07-03 10:50:58  2018
# 1473318  f3b80352b986ab4d1057a4b724be19d0  2018-07-03 10:50:58  2018
# 1473319  f3b80352b986ab4d1057a4b724be19d0  2018-07-03 10:50:58  2018
# 1473320  f3b80352b986ab4d1057a4b724be19d0  2018-07-03 10:50:58  2018
#
#         product_category_name           category  total_price  \
# 0                   telefonia        telephony\r        44.09
# 1                  perfumaria        perfumery\r       201.37
# 2               esporte_lazer   sports_leisure\r       116.93
# 3                  automotivo             auto\r        42.85
# 4            moveis_decoracao  furniture_decor\r        53.72
# ...                       ...                ...          ...
# 1473316          beleza_saude    health_beauty\r       110.58
# 1473317          beleza_saude    health_beauty\r       110.58
# 1473318          beleza_saude    health_beauty\r       110.58
# 1473319          beleza_saude    health_beauty\r       110.58
# 1473320          beleza_saude    health_beauty\r       110.58
#
#                        customer_unique_id customer_state
# 0        71f88676a49942af16839e9690b97f54             RJ
# 1        09f54e88196d12eba479017f13f0e237             SP
# 2        9e4cec36a7f9294540b39950eade4190             MG
# 3        f0903f4311560f0f99dca752df6dfa67             SP
# 4        32c050ea3af0bf160de1209adfb922eb             RJ
# ...                                   ...            ...
# 1473316  04135ea9b5a7f3db234797e55e2d4deb             SP
# 1473317  04135ea9b5a7f3db234797e55e2d4deb             SP
# 1473318  04135ea9b5a7f3db234797e55e2d4deb             SP
# 1473319  04135ea9b5a7f3db234797e55e2d4deb             SP
# 1473320  04135ea9b5a7f3db234797e55e2d4deb             SP
#
# [1473321 rows x 17 columns]

# %%
pd.unique(join_oc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [105], in <cell line: 1>()
# ----> 1 pd.unique(join_oc)
#
# File /opt/anaconda3/envs/DA/lib/python3.9/site-packages/pandas/core/algorithms.py:430, in unique(values)
#     336 def unique(values):
#     337     """
#     338     Return unique values based on a hash table.
#     339
#    (...)
#     428     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     429     """
# --> 430     values = _ensure_arraylike(values)
#     432     if is_extension_array_dtype(values.dtype):
#     433         # Dispatch to extension dtype's unique.
#     434         return values.unique()
#
# File /opt/anaconda3/envs/DA/lib/python3.9/site-packages/pandas/core/algorithms.py:247, in _ensure_arraylike(values)
#     245     if isinstance(values, tuple):
#     246         values = list(values)
# --> 247     values = construct_1d_object_array_from_listlike(values)
#     248 else:
#     249     values = np.asarray(values)
#
# File /opt/anaconda3/envs/DA/lib/python3.9/site-packages/pandas/core/dtypes/cast.py:1983, in construct_1d_object_array_from_listlike(values)
#    1980 # numpy will try to interpret nested lists as further dimensions, hence
#    1981 # making a 1D array that contains list-likes is a bit tricky:
#    1982 result = np.empty(len(values), dtype="object")
# -> 1983 result[:] = values
#    1984 return result
#
# ValueError: could not broadcast input array from shape (1473321,17) into shape (1473321,)

# %%
small = join_oc.drop(['customer_id','customer_city', 'price', 'product_id', 'order_status', 'order_item_id', 'year', 'category', 'customer_state', 'seller_id', 'order_id', 'product_category_name', 'shipping_limit_date', 'total_price'], axis = 1)

# %%
small.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1473321 entries, 0 to 1473320
# Data columns (total 3 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   freight_value       1473321 non-null  float64
#  1   final_price         1473321 non-null  float64
#  2   customer_unique_id  1473321 non-null  object
# dtypes: float64(2), object(1)
# memory usage: 45.0+ MB

# %%
clean_oc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2946641 entries, 0 to 2946640
# Data columns (total 18 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Unnamed: 0             float64
#  1   customer_id            object
#  2   order_id               object
#  3   customer_city          object
#  4   order_status           object
#  5   order_item_id          float64
#  6   price                  float64
#  7   freight_value          float64
#  8   final_price            float64
#  9   product_id             object
#  10  seller_id              object
#  11  shipping_limit_date    object
#  12  year                   float64
#  13  product_category_name  object
#  14  category               object
#  15  total_price            float64
#  16  customer_unique_id     object
#  17  customer_state         object
# dtypes: float64(7), object(11)
# memory usage: 404.7+ MB

# %%
nulls_df = pd.DataFrame(round(clean_oc.isna().sum()/len(clean_oc),4)*100)
nulls_df = nulls_df.reset_index()
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#               header_name  percent_nulls
# 0              Unnamed: 0           50.0
# 1             customer_id            0.0
# 2                order_id            0.0
# 3           customer_city            0.0
# 4            order_status           50.0
# 5           order_item_id           50.0
# 6                   price           50.0
# 7           freight_value           50.0
# 8             final_price           50.0
# 9              product_id           50.0
# 10              seller_id           50.0
# 11    shipping_limit_date           50.0
# 12                   year           50.0
# 13  product_category_name           50.0
# 14               category           50.0
# 15            total_price          100.0
# 16     customer_unique_id          100.0
# 17         customer_state          100.0
